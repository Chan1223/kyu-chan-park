# %% [markdown]
# # Data preparing

# %%
import numpy as np
import pandas as pd

import pickle

# %%
with open('비타민b군제품(1).pickle','rb') as fa:
    data1 = pickle.load(fa)

with open('비타민b군제품(2).pickle','rb') as fb:
    data2 = pickle.load(fb)

with open('비타민b군제품(3).pickle','rb') as fc:
    data3 = pickle.load(fc)

with open('비타민b군제품(4).pickle','rb') as fd:
    data4 = pickle.load(fd)

# %%
data = data1 + data2 + data3 + data4
data[:5]
# Out:
# [('비맥xx타를 능가하는 비타민B군 신제품이 나왔습니다 (육체피로, 정신피로, 구내염, 신경통에 구성 좋은 비타민B군)',
#   '비타민 b군 영양제들이 고약사님 덕에 엄청 뜨니 다른 좋은 제품들도 많이 나오네요. 소비자로서 아주 반가운 상황입니다!'),
#  ('비맥xx타를 능가하는 비타민B군 신제품이 나왔습니다 (육체피로, 정신피로, 구내염, 신경통에 구성 좋은 비타민B군)',
#   '선생님 진짜 초창기부터 인사드리고 했는데 무한성장 선생님을 보니 제가 다 기쁘네요^^ 더욱 더 성장하시고 약을 다루는 최고의 유튜버가 되어주세요\n\n요즘들어 약사님 의견 반영을 많이한 제품들이 많이 나오는거 같은데 개인적으로 가장 베스트도 해주시면 좋을거 같아요'),
#  ('비맥xx타를 능가하는 비타민B군 신제품이 나왔습니다 (육체피로, 정신피로, 구내염, 신경통에 구성 좋은 비타민B군)',
#   '좋은제품 나올때마다 믿을수 있는 약사님이 직접 업데이트 해주셔서 너~~~무 좋아요♡ 감사합니다!!!'),
#  ('비맥xx타를 능가하는 비타민B군 신제품이 나왔습니다 (육체피로, 정신피로, 구내염, 신경통에 구성 좋은 비타민B군)',
#   '비맥스메타가 대박친건 사실상 고약사님이 역할이 매우컸습니다. 아무리 제품이 좋아도 \n그게 발굴되서 \n소비자들에게 알려지지 않으면 말짱도루묵인데 고약사님이 아니었다면 이렇게까지 입소문타고 기존 '),
#  ('비맥xx타를 능가하는 비타민B군 신제품이 나왔습니다 (육체피로, 정신피로, 구내염, 신경통에 구성 좋은 비타민B군)',
#   '약사님때문에 이거 알게 됐지만 역시 약사님때문에 구하기 힘들었어요. 종로 몇 몇 약국에 전화했는데 다 품절... 근데 우리 동네에 있었네요. 방금 구했습니다. 그간 비타민C와 비타민 D는 먹고 있었지만 비타민 B는 그리 신경쓰지 않았는데... 믿고 보는 고약사님!!!')]

# %%
df = pd.DataFrame(data,columns = ['title','comment'])
df.head()
# Out:
#                                                title  \
# 0  비맥xx타를 능가하는 비타민B군 신제품이 나왔습니다 (육체피로, 정신피로, 구내염,...
# 1  비맥xx타를 능가하는 비타민B군 신제품이 나왔습니다 (육체피로, 정신피로, 구내염,...
# 2  비맥xx타를 능가하는 비타민B군 신제품이 나왔습니다 (육체피로, 정신피로, 구내염,...
# 3  비맥xx타를 능가하는 비타민B군 신제품이 나왔습니다 (육체피로, 정신피로, 구내염,...
# 4  비맥xx타를 능가하는 비타민B군 신제품이 나왔습니다 (육체피로, 정신피로, 구내염,...
#
#                                              comment
# 0  비타민 b군 영양제들이 고약사님 덕에 엄청 뜨니 다른 좋은 제품들도 많이 나오네요....
# 1  선생님 진짜 초창기부터 인사드리고 했는데 무한성장 선생님을 보니 제가 다 기쁘네요^...
# 2  좋은제품 나올때마다 믿을수 있는 약사님이 직접 업데이트 해주셔서 너~~~무 좋아요♡...
# 3  비맥스메타가 대박친건 사실상 고약사님이 역할이 매우컸습니다. 아무리 제품이 좋아도 ...
# 4  약사님때문에 이거 알게 됐지만 역시 약사님때문에 구하기 힘들었어요. 종로 몇 몇 약...

# %%
df.shape
# Out:
# (5529, 2)

# %%
df.isnull().sum()
# Out:
# title      0
# comment    0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df['title'].unique()
# Out:
# array(['비맥xx타를 능가하는 비타민B군 신제품이 나왔습니다 (육체피로, 정신피로, 구내염, 신경통에 구성 좋은 비타민B군)',
#        '드디어 정신차린 약국용 피로회복제의 절대강자! 아로나X골드 프리미엄! 과연 얼마나 좋아졌을까요? ( 렛잇X 액티브도 신제품도 알아보았어요!)',
#        '가성비 최고 비타민B군 이걸로 드세요 [해외직구 비타민 리뷰, 피로회복 영양제 추천]',
#        '비타민B군 섭취 중단해야 하는 위험 신호',
#        '이런 비타민제를 복용하고 있다면 중단하세요. (고함량 B군 심장마비 부작용, 제품 고르는법)',
#        '혹시 아직도 안 드세요..?💦 2022년_온유약국 비타민B_추천_최종.mp4',
#        "영양제 여러개 챙겨먹기 힘드시면 '이거 하나면' 충분합니다.( 비타민B, 비타민A, C, E, D, 미네랄이 충분한 품질좋은 '종합비타민')",
#        '꼼꼼 약사가 알려주는 비타민 B 선택법(feat. 비타민 B는 어떻게 만들어질까?)',
#        '요즘 많이 피곤하시죠? 피로회복제 이거 하나만 드셔도 충분한 신제품이 나왔습니다! (비맥x 신제품, x엑스비 듀얼대비 어떤게 더 좋을지?? )',
#        '대한민국의 5대 비타민제 전격 비교!! 신제품 비맥스 메타 비도 함께 보시죠.',
#        '고함량 비타민 B군영양제 !! 이 많은 것 들 중에 대체 뭘 먹지? ( 고함량 비타민 B군비교 분석, 비맥스 메타, 렛잇비, 벤포벨B, 메가트루파워, 엑세라민엑소)',
#        '약사의 비타민B군 100mg대 제품 리뷰, 비맥스메타, 렛잇비, 엑세라민엑소, 벤포벨, 맥스케어, 액티넘EX 뭐가 좋을까',
#        '피로회복을 위한 비타민B 영양제(종합비타민), 총 20종 리뷰를 해 보았습니다! 비맥스 메타, 벤포벨, 임팩타민, 메가트루, 액티넘, 아로나민',
#        '비타민B 그만 먹으라는 신호? 신경독성 논란 정리했어요. 비타민B17, 비타민B100 이런 건 뭔가요',
#        '부작용]비타민B6 신경이 망가집니다. 비타민 B군 안전하게 먹는법',
#        "비타민B 영양제의 최강자는? 야너두 이제 안피곤할 수 있어..!!♥ 약사가 알려주는 '이렇게 선택하세요!' 꿀팁정리~!",
#        '국내 1위 VS 미국 1위 비타민 영양제, 어떤 것이 더 좋을까?',
#        '2022 양과자가 먹고있는 영양제 공개(피로회복, 피부탄력, 에너지, 장건강, 간건강)',
#        '[FAQ] 종합비타민 vs 비타민비군 고함량, 어떤걸 복용해야 할까요??',
#        '약사들의 해외직구 비타민B 리뷰 / #영양제 / #비타민B / #해외직구비타민B',
#        '국내 & 해외 최고의 비타민과 마그네슘 고르는법, 제품 총정리 (피로회복 영양제 조합)',
#        '비타민B! 어떻게 복용해야 할까요? 모르시는 분은 영상 클릭!',
#        '반드시 국산으로 구매해야 하는 영양제들. 이 제품들 만큼은 우리나라가 더 잘만듭니다.',
#        '온가족 영양제 따로 따로 사기 귀찮으셨죠? 비타민B군 하나로 온가족이 다 먹기',
#        '(임팩타민 프리미엄, 비맥스, 엑세라민엑소, 메가트루 포커스) 비타민B군 집중 비교분석',
#        '대사성질환 환자 증가 비타민B 제품 인기', '203. 비타민B군 영양제 추천 이유, 복용법, 고르는 법',
#        '고약사가 섭취하고 있는 영양제를 알려드릴께요!! (이상적인 섭취 방법, 심혈관 질환을 예방하기 위한 영양제 셋팅)',
#        '약국에서 사야 개이득 보는 영양제 알려드려요',
#        '고함량 비타민B, 어떻게 먹어야 할까? 약사가 알려주는 올바른 복용법 및 부작용',
#        '최고의 오메가3, 유산균, 마그네슘, 관절, 고지혈증 영양제 .. 최고의 영양제는 이런걸 드세요! (2021년 최고의 영양제들은 무엇일까요?)',
#        '비타민 B군이 풍부한 최고의 식품',
#        '리틀약사가 파헤쳐 본 아로나민 비타민제품! 활성비타민, 비타민B군이 어디에 좋아요?',
#        '피로회복을 위해 찾는 비타민B군 종합영양제, 어떤걸 먹어야 할까? [약사용설명서]'], dtype=object)

# %%
comments = list(df['comment'])
comments[:5]
# Out:
# ['비타민 b군 영양제들이 고약사님 덕에 엄청 뜨니 다른 좋은 제품들도 많이 나오네요. 소비자로서 아주 반가운 상황입니다!',
#  '선생님 진짜 초창기부터 인사드리고 했는데 무한성장 선생님을 보니 제가 다 기쁘네요^^ 더욱 더 성장하시고 약을 다루는 최고의 유튜버가 되어주세요\n\n요즘들어 약사님 의견 반영을 많이한 제품들이 많이 나오는거 같은데 개인적으로 가장 베스트도 해주시면 좋을거 같아요',
#  '좋은제품 나올때마다 믿을수 있는 약사님이 직접 업데이트 해주셔서 너~~~무 좋아요♡ 감사합니다!!!',
#  '비맥스메타가 대박친건 사실상 고약사님이 역할이 매우컸습니다. 아무리 제품이 좋아도 \n그게 발굴되서 \n소비자들에게 알려지지 않으면 말짱도루묵인데 고약사님이 아니었다면 이렇게까지 입소문타고 기존 ',
#  '약사님때문에 이거 알게 됐지만 역시 약사님때문에 구하기 힘들었어요. 종로 몇 몇 약국에 전화했는데 다 품절... 근데 우리 동네에 있었네요. 방금 구했습니다. 그간 비타민C와 비타민 D는 먹고 있었지만 비타민 B는 그리 신경쓰지 않았는데... 믿고 보는 고약사님!!!']

# %%
df.to_csv('dataframe.csv')

# %% [markdown]
# # Tokenization

# %%
pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 921 kB/s  eta 0:00:01
# Requirement already satisfied: lxml>=4.1.0 in /Users/chan/opt/anaconda3/lib/python3.9/site-packages (from konlpy) (4.6.3)
# Requirement already satisfied: numpy>=1.6 in /Users/chan/opt/anaconda3/lib/python3.9/site-packages (from konlpy) (1.20.3)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.0-cp39-cp39-macosx_10_9_x86_64.whl (381 kB)
#      |████████████████████████████████| 381 kB 10.3 MB/s eta 0:00:01
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.0 konlpy-0.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from konlpy.tag import Okt

# %%
okt = Okt()

# %%
#https://gist.githubusercontent.com/chulgil/d10b18575a73778da4bc83853385465c/raw/a1a451421097fa9a93179cb1f1f0dc392f1f9da9/stopwords.txt
with open('/content/drive/MyDrive/stopwords_korean.txt',encoding='cp949') as f:
    stopwords = f.readlines()
    stopwords = [word.strip() for word in stopwords]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/42/6b83dcy962qg0qxnnz4ck_8c0000gn/T/ipykernel_47225/1753676835.py in <module>
#       1 #https://gist.githubusercontent.com/chulgil/d10b18575a73778da4bc83853385465c/raw/a1a451421097fa9a93179cb1f1f0dc392f1f9da9/stopwords.txt
# ----> 2 with open('/content/drive/MyDrive/stopwords_korean.txt',encoding='cp949') as f:
#       3     stopwords = f.readlines()
#       4     stopwords = [word.strip() for word in stopwords]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/stopwords_korean.txt'

# %%
stopwords.extend(['요','저','제','좀','것','더','군','혹시','보고','거','민','가요','중'])

# %%
filtered_sent = []
for i, document in enumerate(comments):
    clean_words = []
    for word in okt.pos(document, stem=True): #어간 추출
        if word[1] == 'Noun' and word[0] not in stopwords: #명사, 동사, 형용사
            clean_words.append(word[0])
    document = ' '.join(clean_words)
    filtered_sent.append(document)

# %%
filtered_sent[:5]
# Out:
# ['비타민 양제 약사 덕 제품 소비자 로서 아주 상황',
#  '선생님 진짜 초창 기 인사 무한 성장 선생님 더욱 약 최고 유튜버 요즘 약사 의견 반영 제품 개인 가장 베스트 해주시',
#  '제품 약사 직접 업데이트 무',
#  '비 맥스 메타 대박 사실 약사 역할 매우 제품 그게 발굴 소비자 도루묵 약사 입소 타고 기존',
#  '약사 때문 알 역시 약사 때문 종로 약국 품절 동네 방금 그간 비타민 비타민 비타민 신경 약사']

# %%
from collections import Counter

# %%
words_list = [doc.strip().split() for doc in filtered_sent]
words_list[:5]
# Out:
# [['비타민', '양제', '약사', '덕', '제품', '소비자', '로서', '아주', '상황'],
#  ['선생님',
#   '진짜',
#   '초창',
#   '기',
#   '인사',
#   '무한',
#   '성장',
#   '선생님',
#   '더욱',
#   '약',
#   '최고',
#   '유튜버',
#   '요즘',
#   '약사',
#   '의견',
#   '반영',
#   '제품',
#   '개인',
#   '가장',
#   '베스트',
#   '해주시'],
#  ['제품', '약사', '직접', '업데이트', '무'],
#  ['비',
#   '맥스',
#   '메타',
#   '대박',
#   '사실',
#   '약사',
#   '역할',
#   '매우',
#   '제품',
#   '그게',
#   '발굴',
#   '소비자',
#   '도루묵',
#   '약사',
#   '입소',
#   '타고',
#   '기존'],
#  ['약사',
#   '때문',
#   '알',
#   '역시',
#   '약사',
#   '때문',
#   '종로',
#   '약국',
#   '품절',
#   '동네',
#   '방금',
#   '그간',
#   '비타민',
#   '비타민',
#   '비타민',
#   '신경',
#   '약사']]

# %%
total_words = []
for words in words_list:
    total_words.extend(words)

# %%
len(total_words)
# Out:
# 50816

# %%
c = Counter(total_words)
dict_c = dict(c)
dict_c
# Out:
# {'비타민': 1801,
#  '양제': 848,
#  '약사': 1486,
#  '덕': 10,
#  '제품': 983,
#  '소비자': 35,
#  '로서': 6,
#  '아주': 23,
#  '상황': 12,
#  '선생님': 242,
#  '진짜': 73,
#  '초창': 7,
#  '기': 18,
#  '인사': 9,
#  '무한': 2,
#  '성장': 5,
#  '더욱': 8,
#  '약': 527,
#  '최고': 61,
#  '유튜버': 25,
#  '요즘': 104,
#  '의견': 19,
#  '반영': 3,
#  '개인': 25,
#  '가장': 40,
#  '베스트': 58,
#  '해주시': 18,
#  '직접': 12,
#  '업데이트': 1,
#  '무': 7,
#  '비': 1137,
#  '맥스': 653,
#  '메타': 449,
#  '대박': 11,
#  '사실': 24,
#  '역할': 3,
#  '매우': 11,
#  '그게': 14,
#  '발굴': 1,
#  '도루묵': 1,
#  '입소': 1,
#  '타고': 3,
#  '기존': 23,
#  '때문': 154,
#  '알': 384,
#  '역시': 31,
#  '종로': 7,
#  '약국': 187,
#  '품절': 31,
#  '동네': 9,
#  '방금': 7,
#  '그간': 3,
#  '신경': 32,
#  '꼭': 97,
#  '사람': 171,
#  '소개': 122,
#  '전': 154,
#  '비맥땡': 36,
#  '이건': 22,
#  '식후': 54,
#  '이전': 13,
#  '소화': 33,
#  '별문제': 2,
#  '식전': 17,
#  '고령': 3,
#  '세': 67,
#  '노인': 4,
#  '밥맛': 2,
#  '기력': 6,
#  '추천': 703,
#  '덕분': 116,
#  '계속': 112,
#  '박스': 12,
#  '항상': 334,
#  '정말': 165,
#  '수고': 17,
#  '늘': 137,
#  '섭취': 368,
#  '공복': 51,
#  '흡수': 43,
#  '율': 19,
#  '두드러기': 13,
#  '무릎': 16,
#  '쪽': 26,
#  '부어': 5,
#  '감': 49,
#  '올해': 27,
#  '영상': 658,
#  '도움': 260,
#  '크롬': 4,
#  '이노시톨': 5,
#  '콜린': 5,
#  '배합': 4,
#  '차이': 64,
#  '번갈아': 13,
#  '대한': 27,
#  '정보': 422,
#  '현재': 95,
#  '케이': 5,
#  '투': 14,
#  '미네랄': 51,
#  '부스터': 17,
#  '복용': 836,
#  '추가': 137,
#  '투엑스': 83,
#  '듀얼': 101,
#  '아연': 101,
#  '함량': 226,
#  '스터': 1,
#  '글': 40,
#  '루콘': 1,
#  '산': 20,
#  '구리': 6,
#  '산화': 4,
#  '트롬': 7,
#  '간만': 2,
#  '나름': 9,
#  '효과': 193,
#  '이제': 61,
#  '만성': 10,
#  '느낌': 60,
#  '말씀': 119,
#  '새': 1,
#  '시중': 9,
#  '판매': 31,
#  '가격': 152,
#  '배': 28,
#  '정': 86,
#  '평소': 47,
#  '대해': 62,
#  '이유': 61,
#  '질문': 131,
#  '남성': 29,
#  '퓨어': 6,
#  '원': 4,
#  '마그네슘': 337,
#  '나우': 33,
#  '울트라': 6,
#  '오메가': 492,
#  '비씨': 1,
#  '재': 10,
#  '로우': 13,
#  '유산균': 228,
#  '헬스': 9,
#  '오리진': 1,
#  '피크': 14,
#  '노': 15,
#  '놀': 13,
#  '면역': 18,
#  '억제제': 4,
#  '강황': 14,
#  '주의': 13,
#  '제나': 14,
#  '칼슘': 135,
#  '제등': 4,
#  '알약': 37,
#  '커서': 9,
#  '영양': 108,
#  '율등': 1,
#  '상관': 10,
#  '한편': 5,
#  '간접': 1,
#  '광고': 135,
#  '양심': 4,
#  '경우': 87,
#  '개': 90,
#  '세트': 3,
#  '곳': 22,
#  '기도': 10,
#  '점점': 12,
#  '기분': 20,
#  '길거리': 1,
#  '장사': 3,
#  '누군가': 3,
#  '팔고': 5,
#  '부분': 36,
#  '수험생': 58,
#  '아침': 118,
#  '물건': 2,
#  '이후': 16,
#  '기회': 4,
#  '호': 1,
#  '임팩타민': 73,
#  '프리미엄': 82,
#  '원스': 13,
#  '나중': 10,
#  '종합': 414,
#  '비교': 104,
#  '우물': 1,
#  '안': 109,
#  '개구리': 1,
#  '마냥': 2,
#  '로나': 124,
#  '비콤': 1,
#  '생각': 116,
#  '인': 26,
#  '유튜브': 45,
#  '최근': 63,
#  '불면증': 31,
#  '시청': 36,
#  '관련': 37,
#  '주신': 29,
#  '월요일': 4,
#  '스비': 1,
#  '만': 66,
#  '거저': 1,
#  '숫자': 6,
#  '고민': 90,
#  '성분': 150,
#  '표': 19,
#  '확인': 20,
#  '처음': 67,
#  '접': 7,
#  '부부': 5,
#  '용량': 98,
#  '부작용': 173,
#  '의사': 33,
#  '철분': 23,
#  '포함': 40,
#  '신장기': 1,
#  '능이': 1,
#  '조심': 5,
#  '괜찬': 9,
#  '한국': 24,
#  '수': 129,
#  '활': 94,
#  '최강': 3,
#  '설부': 1,
#  '티아민': 47,
#  '판토': 7,
#  '액': 18,
#  '세라': 88,
#  '아미': 3,
#  '벤조산': 1,
#  '질산염': 6,
#  '판토텐산': 16,
#  '걸': 131,
#  '하루': 251,
#  '번': 74,
#  '해당': 16,
#  '염려': 2,
#  '연기': 13,
#  '재미': 3,
#  '솔솔': 1,
#  '메스': 2,
#  '한번': 133,
#  '해': 46,
#  '권': 23,
#  '장량': 20,
#  '는걸': 14,
#  '눈': 83,
#  '피로': 177,
#  '시력': 4,
#  '보호': 4,
#  '목적': 21,
#  '위': 94,
#  '예전': 49,
#  '구매': 189,
#  '말': 95,
#  '수치': 38,
#  '씬': 2,
#  '록': 2,
#  '신정': 3,
#  '리': 38,
#  '스': 26,
#  '저녁': 72,
#  '식사': 34,
#  '기능': 39,
#  '보기': 19,
#  '갑상선': 23,
#  '점심': 62,
#  '코드': 11,
#  '걱정': 65,
#  '실제': 9,
#  '통': 43,
#  '그냥': 77,
#  '중단': 61,
#  '부담': 31,
#  '방법': 31,
#  '두': 27,
#  '편': 26,
#  '케어': 37,
#  '며칠': 16,
#  '선물': 19,
#  '회복': 72,
#  '장기': 20,
#  '해도': 54,
#  '돌발': 1,
#  '난청': 1,
#  '청력': 1,
#  '남편': 46,
#  '공부': 70,
#  '야간': 7,
#  '근무': 9,
#  '보안': 2,
#  '비등': 2,
#  '비타': 32,
#  '목': 14,
#  '자주': 56,
#  '비맥': 26,
#  '작년': 16,
#  '겨울': 2,
#  '완전': 12,
#  '강추': 1,
#  '전도사': 2,
#  '설명': 119,
#  '중학생': 17,
#  '애': 12,
#  '입안': 9,
#  '입': 8,
#  '주위': 6,
#  '피부': 43,
#  '입술': 11,
#  '꼬리': 1,
#  '렛잇비': 79,
#  '부모님': 42,
#  '겹': 12,
#  '소변': 27,
#  '배출': 16,
#  '타': 13,
#  '도': 107,
#  '간수치': 45,
#  '자제': 3,
#  '간': 120,
#  '크게': 27,
#  '무리': 46,
#  '가지': 104,
#  '안나': 5,
#  '땡': 129,
#  '기간': 14,
#  '개월': 42,
#  '중이': 20,
#  '차': 15,
#  '구입': 137,
#  '주': 14,
#  '정도': 154,
#  '주일': 3,
#  '자꾸': 23,
#  '헛구역질': 3,
#  '단가': 5,
#  '메': 81,
#  '코발라민': 46,
#  '먹기': 67,
#  '비멕땡': 2,
#  '신제품': 29,
#  '초록색': 2,
#  '구내염': 35,
#  '시작': 65,
#  '벌써': 20,
#  '가나': 4,
#  '오줌': 9,
#  '색': 14,
#  '상이': 9,
#  '고혈압약': 8,
#  '글루': 31,
#  '타치': 32,
#  '온': 35,
#  '루테': 55,
#  '장점': 4,
#  '유투브': 25,
#  '니': 35,
#  '은': 36,
#  '액티브': 23,
#  '엑스': 44,
#  '보충': 32,
#  '보통': 20,
#  '사서': 32,
#  '제겐': 1,
#  '속': 27,
#  '두통': 32,
#  '엄마': 48,
#  '이안': 3,
#  '습': 18,
#  '류': 11,
#  '중독': 3,
#  '성은': 2,
#  '게': 59,
#  '활동': 11,
#  '형': 14,
#  '간염': 19,
#  '보균자': 9,
#  '방송': 32,
#  '여자': 22,
#  '보유': 1,
#  '이군': 6,
#  '오늘': 98,
#  '몸': 123,
#  '실험': 2,
#  '제의': 10,
#  '끝판': 1,
#  '급임': 1,
#  '대웅제약': 11,
#  '병원': 58,
#  '처방': 39,
#  '내일': 7,
#  '근육': 12,
#  '개선': 27,
#  '정량': 5,
#  '구토': 11,
#  '드': 20,
#  '물': 35,
#  '연예인': 36,
#  '가까이': 5,
#  '국가': 13,
#  '라이프': 56,
#  '익스': 29,
#  '텐션': 27,
#  '투퍼': 92,
#  '데이': 102,
#  '뭘': 50,
#  '분도': 3,
#  '뭐': 99,
#  '마비': 83,
#  '마씨': 1,
#  '위주': 7,
#  '밀크': 50,
#  '슬': 24,
#  '고함': 3,
#  '손톱': 5,
#  '얼라이브': 27,
#  '구미': 5,
#  '건강': 175,
#  '화이팅': 63,
#  '빠': 5,
#  '이염': 2,
#  '해외': 49,
#  '달리': 6,
#  '첨가제': 2,
#  '후': 121,
#  '고려': 31,
#  '은단': 15,
#  '한가지': 32,
#  '아들': 25,
#  '이구': 10,
#  '부신': 3,
#  '저하': 22,
#  '호르몬': 10,
#  '집중': 4,
#  '얼굴': 60,
#  '색도': 1,
#  '향': 7,
#  '무조건': 15,
#  '편균': 1,
#  '대로': 6,
#  '어머니': 54,
#  '혈액': 13,
#  '검사': 52,
#  '참고': 52,
#  '터': 9,
#  '글루콤': 8,
#  '고': 42,
#  '음료': 6,
#  '오후': 7,
#  '졸음': 8,
#  '퇴치': 1,
#  '장복': 8,
#  '포커스': 9,
#  '제도': 51,
#  '피엠': 2,
#  '폴': 2,
#  '산정': 1,
#  '하셧는데': 2,
#  '약장': 1,
#  '사의': 12,
#  '담': 10,
#  '제약회사': 9,
#  '선택': 56,
#  '의심': 7,
#  '글치': 1,
#  '중학교': 2,
#  '입학': 1,
#  '지금': 160,
#  '보넷': 26,
#  '리서치': 199,
#  '짜증': 2,
#  '카탈리스트': 1,
#  '서도': 17,
#  '인지': 16,
#  '잔틴': 8,
#  '증상': 69,
#  '스포츠': 35,
#  '블루': 32,
#  '킬레이트': 23,
#  '거나': 19,
#  '문제': 82,
#  '감안': 2,
#  '마침': 9,
#  '세번': 6,
#  '모름': 1,
#  '도저히': 3,
#  '가성': 34,
#  '일부러': 5,
#  '당뇨': 63,
#  '운동': 58,
#  '걷기': 2,
#  '만하': 7,
#  '족저근막염': 3,
#  '발바닥': 1,
#  '다리': 16,
#  '근육통': 24,
#  '심해': 9,
#  '약도': 18,
#  '변화': 6,
#  '혈당': 6,
#  '가끔': 29,
#  '순환': 9,
#  '땐': 19,
#  '정상': 20,
#  '고견': 6,
#  '답변': 96,
#  '업': 6,
#  '그레이': 1,
#  '경쟁': 4,
#  '달': 64,
#  '결론': 8,
#  '여성': 43,
#  '타겟': 1,
#  '친구': 9,
#  '덜': 13,
#  '급': 3,
#  '관심': 33,
#  '성형': 94,
#  '건가': 85,
#  '엽산': 43,
#  '갱년기': 17,
#  '메틸': 23,
#  '비활': 26,
#  '국내': 73,
#  '다시': 47,
#  '직구': 135,
#  '아기': 3,
#  '건강검진': 12,
#  '자극': 4,
#  '증가': 4,
#  '백혈구': 1,
#  '수가': 6,
#  '감소': 5,
#  '적혈구': 1,
#  '고혈압': 27,
#  '콜레스테롤': 10,
#  '상승': 5,
#  '고박사님': 6,
#  '남학생': 5,
#  '기립': 7,
#  '저혈압': 20,
#  '시험': 10,
#  '교실': 1,
#  '적도': 1,
#  '체력': 23,
#  '짐': 4,
#  '트루': 119,
#  '큐업': 1,
#  '먹이': 18,
#  '두피': 4,
#  '여드름': 25,
#  '별거': 2,
#  '지루': 5,
#  '염': 32,
#  '포진': 10,
#  '때메': 2,
#  '비비': 8,
#  '문제점': 3,
#  '부형제': 3,
#  '첨가': 12,
#  '모든': 18,
#  '물이': 7,
#  '난': 9,
#  '임부': 1,
#  '부라': 1,
#  '난임': 1,
#  '조합': 56,
#  '연골': 5,
#  '여러가지': 15,
#  '설': 23,
#  '엑소': 62,
#  '낫': 5,
#  '프로': 39,
#  '최대한': 4,
#  '이틀': 13,
#  '몸무게': 4,
#  '기준': 24,
#  '성인': 15,
#  '키': 12,
#  '면': 16,
#  '슈퍼': 17,
#  '뉴': 29,
#  '트리': 33,
#  '션': 11,
#  '비맥떙': 2,
#  '함': 17,
#  '복욕': 4,
#  '마무': 2,
#  '런': 4,
#  '얼': 6,
#  '공도': 1,
#  '젠': 21,
#  '유튜': 1,
#  '바': 11,
#  '시아노': 17,
#  '극미': 2,
#  '량': 16,
#  '청산': 5,
#  '이면': 14,
#  '독자': 91,
#  '독일': 3,
#  '나시': 2,
#  '리뷰': 34,
#  '리트': 3,
#  '취향': 1,
#  '역류성': 8,
#  '식도염': 13,
#  '고등어': 1,
#  '주정': 2,
#  '비염': 12,
#  '치료': 23,
#  '상세': 13,
#  '고등학생': 13,
#  '수업': 1,
#  '지장': 6,
#  '리틀': 22,
#  '거기': 13,
#  '출시': 12,
#  '수용성': 12,
#  '게더': 1,
#  '알츠하이머': 1,
#  '데': 66,
#  '부탁': 53,
#  '락토': 10,
#  '비프': 9,
#  '거리': 16,
#  '가스': 3,
#  '차고': 4,
#  '부글': 1,
#  '방귀': 3,
#  '냄새': 54,
#  '가야': 6,
#  '감사': 175,
#  '점': 39,
#  '연세': 3,
#  '푸록틴': 1,
#  '캡슐': 44,
#  '트라린정': 1,
#  '나제': 1,
#  '파': 4,
#  '록스': 1,
#  '알정': 1,
#  '줗': 2,
#  '어르신': 8,
#  '고질': 2,
#  '손목': 5,
#  '어깨': 17,
#  '통증': 48,
#  '진통제': 11,
#  '궁금': 9,
#  '컴플렉스': 30,
#  '메이플': 1,
#  '캐나다': 9,
#  '동영상': 16,
#  '밑': 1,
#  '식품': 34,
#  '노파': 1,
#  '심': 9,
#  '울': 4,
#  '타우린': 5,
#  '주사': 9,
#  '뭔가': 45,
#  '묘': 3,
#  '닥터스': 36,
#  '솔': 36,
#  '멀티': 104,
#  '동시': 13,
#  '종일': 15,
#  '답': 16,
#  '골다공증': 16,
#  '시': 55,
#  '새벽': 12,
#  '밤새': 1,
#  '술': 28,
#  '홍조': 10,
#  '어골': 2,
#  '티비': 12,
#  '헤': 3,
#  '실수': 8,
#  '위장병': 1,
#  '신경통': 5,
#  '긴장': 3,
#  '암웨이': 8,
#  '옥': 5,
#  '사코': 3,
#  '청심환': 1,
#  '원래': 31,
#  '민비': 6,
#  '놀이': 2,
#  '댓글': 77,
#  '답글': 9,
#  '신분': 8,
#  '롱런': 4,
#  '골드': 124,
#  '정리': 58,
#  '표기': 8,
#  '허브': 26,
#  '니켈': 2,
#  '코발트': 2,
#  '알러지': 9,
#  '위장': 51,
#  '커피': 13,
#  '스타일': 2,
#  '고등': 5,
#  '딸아이': 6,
#  '요것': 2,
#  '포티': 31,
#  '아민': 31,
#  '나머지': 11,
#  '아빠': 5,
#  '스트레스': 32,
#  '집': 22,
#  '그린': 4,
#  '프로폴리스': 22,
#  '한일': 2,
#  '저체중': 1,
#  '딸': 6,
#  '어제': 18,
#  '센트': 30,
#  '륨': 7,
#  '괜': 11,
#  '비땡': 2,
#  '상보': 10,
#  '괜시리': 1,
#  '비엘': 2,
#  '포벨': 27,
#  '못': 37,
#  '용': 58,
#  '워치': 1,
#  '무방': 3,
#  '육체파': 1,
#  '메모': 6,
#  '필수': 15,
#  '비유': 3,
#  '고정': 2,
#  '비멕': 1,
#  '욤': 6,
#  '다낭': 2,
#  '증후군': 14,
#  '즐': 5,
#  '코': 6,
#  '발아': 2,
#  '메틸코': 1,
#  '의미': 4,
#  '쉬': 6,
#  '리스트': 2,
#  '아래': 12,
#  '준비': 29,
#  '초이스': 3,
#  '날': 45,
#  '구독': 138,
#  '미국': 30,
#  '크기': 5,
#  '조만간': 2,
#  '드라마': 1,
#  '팀': 3,
#  '연락': 4,
#  '자연': 5,
#  '부족': 14,
#  '가려움': 3,
#  '바이타민': 1,
#  '에버': 8,
#  '방': 8,
#  '양방': 1,
#  '유한': 8,
#  '메카': 1,
#  '투루': 3,
#  '파워': 21,
#  '베이직': 30,
#  '콤플렉스': 7,
#  '레시틴': 11,
#  '주문': 26,
#  '군도': 3,
#  '볼': 26,
#  '실리': 16,
#  '포스': 9,
#  '시슬': 25,
#  '주변': 13,
#  '보': 25,
#  '호주': 1,
#  '헬': 4,
#  '지방간': 16,
#  '서서': 4,
#  '중반': 30,
#  '판단': 5,
#  '내용': 42,
#  '걱': 1,
#  '영향력': 21,
#  '각인': 1,
#  '그것': 8,
#  '은줄': 4,
#  '비용': 7,
#  '대안': 2,
#  '바타': 3,
#  '멀리': 3,
#  '강원도': 1,
#  '검색': 26,
#  '온라인': 5,
#  '성지': 3,
#  '가면': 14,
#  '반값': 2,
#  '살': 61,
#  '우위': 1,
#  '듯': 31,
#  '비오틴': 41,
#  '요새': 18,
#  '육체': 19,
#  '정신': 17,
#  '자도': 12,
#  '던데': 9,
#  '강점': 1,
#  '어린이': 8,
#  '인터넷': 18,
#  '맥주': 14,
#  '효모': 15,
#  '언급': 17,
#  '임신': 27,
#  '개중': 3,
#  '아침식사': 5,
#  '승': 2,
#  '나은': 7,
#  '아사이베리': 1,
#  '푸드': 19,
#  '사별': 1,
#  '굳이': 25,
#  '상품': 23,
#  '효능': 11,
#  '얘기': 28,
#  '찌린내': 1,
#  '보조': 16,
#  '컨디션': 10,
#  '체감': 8,
#  '식곤증': 2,
#  '홍삼': 12,
#  '그동안': 11,
#  '커큐민': 11,
#  '하나요': 42,
#  '삐': 3,
#  '군특유': 1,
#  '맛': 6,
#  '붓기': 6,
#  '기상': 4,
#  '경도': 1,
#  '소질': 1,
#  '별로': 32,
#  '거래': 2,
#  '군데': 9,
#  '일주일': 21,
#  '매스': 5,
#  '움': 4,
#  '녹차': 6,
#  '홍차': 4,
#  '비텐': 2,
#  '임펙타민': 14,
#  '아시': 21,
#  '분': 61,
#  '계시': 36,
#  '최소': 3,
#  '땡땡': 51,
#  '총': 19,
#  '종비': 28,
#  '종근당': 11,
#  '앤': 4,
#  '마린': 11,
#  '군산': 1,
#  '동생': 10,
#  '웃프': 1,
#  '주시': 43,
#  '믿음': 14,
#  '낫다': 6,
#  '사고': 10,
#  '군대': 3,
#  '경찰': 2,
#  '공무원': 3,
#  '병행': 8,
#  '비멕스': 24,
#  '가수': 5,
#  '변비': 13,
#  '건': 56,
#  '친정엄마': 4,
#  '절제': 4,
#  '간암': 3,
#  '색전술': 2,
#  '몇번': 4,
#  '친정': 3,
#  '사드': 6,
#  '려': 5,
#  '통풍': 44,
#  '대가': 11,
#  '수유': 2,
#  '부가': 2,
#  '파급': 1,
#  '세진': 1,
#  '과장': 4,
#  '팩트': 10,
#  '영양소': 41,
#  '특정': 2,
#  '불안': 3,
#  '놈': 3,
#  '승자': 1,
#  '비리': 6,
#  '유효': 3,
#  '기업': 4,
#  '저가': 4,
#  '율도': 1,
#  '노시': 1,
#  '룸': 23,
#  '사어': 1,
#  '먹음': 20,
#  '남': 8,
#  '카르': 1,
#  '장애': 41,
#  '슴': 2,
#  '이분': 7,
#  '판': 3,
#  '일제': 2,
#  '빌라': 1,
#  '투퍼데': 15,
#  '환자': 51,
#  '괸': 1,
#  '티': 17,
#  '화학': 7,
#  '유명': 5,
#  '흡연': 27,
#  '라이신': 10,
#  '헤르페스': 8,
#  '결정': 8,
#  '핑돈다': 1,
#  '파란색': 3,
#  '남자': 29,
#  '용이': 8,
#  '빨간색': 3,
#  '간이': 23,
#  '근처': 9,
#  '복': 31,
#  '영하': 1,
#  '눈밑': 4,
#  '지방': 4,
#  '이생': 1,
#  '겨': 5,
#  '비큐': 1,
#  '텐액티브': 1,
#  '이세': 4,
#  '비트': 2,
#  '서요': 8,
#  '중복': 19,
#  '소름': 1,
#  '자리': 3,
#  '유튭': 5,
#  '이름': 47,
#  '땡액스비': 1,
#  '모델': 37,
#  '갓': 1,
#  '발': 12,
#  '우루사': 13,
#  '미리': 19,
#  '손': 30,
#  '혈압': 28,
#  '플라크': 1,
#  '뇌경색': 4,
#  '가족': 29,
#  '전혀': 12,
#  '어마': 2,
#  '무시': 4,
#  '내': 14,
#  '화가': 6,
#  '전화': 5,
#  '반': 25,
#  '짤': 3,
#  '반개': 2,
#  '골': 13,
#  '알땡': 1,
#  '를더': 1,
#  '제일': 30,
#  '그거': 13,
#  '샀는뎁': 1,
#  '편이': 14,
#  '범주': 1,
#  '트': 32,
#  '뾰': 1,
#  '갑자기': 27,
#  '뒤': 19,
#  '자고': 8,
#  '보아': 2,
#  '정맥': 2,
#  '안직안': 1,
#  '전체': 6,
#  '고지': 1,
#  '증': 33,
#  '투액스땡': 1,
#  '셀': 7,
#  '디자인': 3,
#  '포': 18,
#  '장': 16,
#  '한텐': 5,
#  '신장': 37,
#  ...}

# %%
c2 = sorted(dict_c.items(), key=lambda x: x[1],reverse=True)

# %%
c2
# Out:
# [('비타민', 1801),
#  ('약사', 1486),
#  ('비', 1137),
#  ('제품', 983),
#  ('양제', 848),
#  ('복용', 836),
#  ('추천', 703),
#  ('영상', 658),
#  ('맥스', 653),
#  ('약', 527),
#  ('오메가', 492),
#  ('메타', 449),
#  ('정보', 422),
#  ('종합', 414),
#  ('알', 384),
#  ('축하', 369),
#  ('섭취', 368),
#  ('마그네슘', 337),
#  ('항상', 334),
#  ('도움', 260),
#  ('하루', 251),
#  ('선생님', 242),
#  ('유산균', 228),
#  ('함량', 226),
#  ('리서치', 199),
#  ('효과', 193),
#  ('구매', 189),
#  ('약국', 187),
#  ('피로', 177),
#  ('건강', 175),
#  ('감사', 175),
#  ('부작용', 173),
#  ('사람', 171),
#  ('정말', 165),
#  ('지금', 160),
#  ('때문', 154),
#  ('전', 154),
#  ('정도', 154),
#  ('가격', 152),
#  ('성분', 150),
#  ('구독', 138),
#  ('늘', 137),
#  ('추가', 137),
#  ('구입', 137),
#  ('칼슘', 135),
#  ('광고', 135),
#  ('직구', 135),
#  ('한번', 133),
#  ('질문', 131),
#  ('걸', 131),
#  ('수', 129),
#  ('땡', 129),
#  ('로나', 124),
#  ('골드', 124),
#  ('몸', 123),
#  ('소개', 122),
#  ('후', 121),
#  ('간', 120),
#  ('말씀', 119),
#  ('설명', 119),
#  ('트루', 119),
#  ('아침', 118),
#  ('덕분', 116),
#  ('생각', 116),
#  ('계속', 112),
#  ('안', 109),
#  ('영양', 108),
#  ('도', 107),
#  ('요즘', 104),
#  ('비교', 104),
#  ('가지', 104),
#  ('멀티', 104),
#  ('데이', 102),
#  ('듀얼', 101),
#  ('아연', 101),
#  ('뭐', 99),
#  ('용량', 98),
#  ('오늘', 98),
#  ('꼭', 97),
#  ('답변', 96),
#  ('현재', 95),
#  ('말', 95),
#  ('활', 94),
#  ('위', 94),
#  ('성형', 94),
#  ('투퍼', 92),
#  ('독자', 91),
#  ('개', 90),
#  ('고민', 90),
#  ('앞', 90),
#  ('세라', 88),
#  ('경우', 87),
#  ('정', 86),
#  ('건가', 85),
#  ('투엑스', 83),
#  ('눈', 83),
#  ('마비', 83),
#  ('프리미엄', 82),
#  ('문제', 82),
#  ('메', 81),
#  ('렛잇비', 79),
#  ('자료', 78),
#  ('그냥', 77),
#  ('댓글', 77),
#  ('번', 74),
#  ('진짜', 73),
#  ('임팩타민', 73),
#  ('국내', 73),
#  ('저녁', 72),
#  ('회복', 72),
#  ('공부', 70),
#  ('증상', 69),
#  ('세', 67),
#  ('처음', 67),
#  ('먹기', 67),
#  ('만', 66),
#  ('데', 66),
#  ('걱정', 65),
#  ('시작', 65),
#  ('차이', 64),
#  ('달', 64),
#  ('최근', 63),
#  ('화이팅', 63),
#  ('당뇨', 63),
#  ('대해', 62),
#  ('점심', 62),
#  ('엑소', 62),
#  ('최고', 61),
#  ('이제', 61),
#  ('이유', 61),
#  ('중단', 61),
#  ('살', 61),
#  ('분', 61),
#  ('디', 61),
#  ('관절', 61),
#  ('느낌', 60),
#  ('얼굴', 60),
#  ('게', 59),
#  ('베스트', 58),
#  ('수험생', 58),
#  ('병원', 58),
#  ('운동', 58),
#  ('정리', 58),
#  ('용', 58),
#  ('닥터', 58),
#  ('채널', 57),
#  ('매일', 57),
#  ('자주', 56),
#  ('라이프', 56),
#  ('선택', 56),
#  ('조합', 56),
#  ('건', 56),
#  ('루테', 55),
#  ('시', 55),
#  ('아르기닌', 55),
#  ('문의', 55),
#  ('코큐텐', 55),
#  ('백만', 55),
#  ('식후', 54),
#  ('해도', 54),
#  ('어머니', 54),
#  ('냄새', 54),
#  ('부탁', 53),
#  ('추카', 53),
#  ('검사', 52),
#  ('참고', 52),
#  ('공복', 51),
#  ('미네랄', 51),
#  ('제도', 51),
#  ('위장', 51),
#  ('땡땡', 51),
#  ('환자', 51),
#  ('뭘', 50),
#  ('밀크', 50),
#  ('감', 49),
#  ('예전', 49),
#  ('해외', 49),
#  ('엄마', 48),
#  ('통증', 48),
#  ('잠', 48),
#  ('평소', 47),
#  ('티아민', 47),
#  ('다시', 47),
#  ('이름', 47),
#  ('해', 46),
#  ('남편', 46),
#  ('무리', 46),
#  ('코발라민', 46),
#  ('유튜브', 45),
#  ('간수치', 45),
#  ('뭔가', 45),
#  ('날', 45),
#  ('엑스', 44),
#  ('캡슐', 44),
#  ('통풍', 44),
#  ('진심', 44),
#  ('흡수', 43),
#  ('통', 43),
#  ('피부', 43),
#  ('여성', 43),
#  ('엽산', 43),
#  ('주시', 43),
#  ('부모님', 42),
#  ('개월', 42),
#  ('고', 42),
#  ('내용', 42),
#  ('하나요', 42),
#  ('비오틴', 41),
#  ('영양소', 41),
#  ('장애', 41),
#  ('가장', 40),
#  ('글', 40),
#  ('포함', 40),
#  ('종류', 40),
#  ('기능', 39),
#  ('처방', 39),
#  ('프로', 39),
#  ('점', 39),
#  ('수치', 38),
#  ('리', 38),
#  ('나이', 38),
#  ('응원', 38),
#  ('콜라겐', 38),
#  ('고지혈증', 38),
#  ('알티', 38),
#  ('알약', 37),
#  ('관련', 37),
#  ('케어', 37),
#  ('못', 37),
#  ('모델', 37),
#  ('신장', 37),
#  ('국산', 37),
#  ('비맥땡', 36),
#  ('부분', 36),
#  ('시청', 36),
#  ('은', 36),
#  ('연예인', 36),
#  ('닥터스', 36),
#  ('솔', 36),
#  ('계시', 36),
#  ('소비자', 35),
#  ('구내염', 35),
#  ('온', 35),
#  ('니', 35),
#  ('물', 35),
#  ('스포츠', 35),
#  ('돈', 35),
#  ('녹십자', 35),
#  ('식사', 34),
#  ('가성', 34),
#  ('리뷰', 34),
#  ('식품', 34),
#  ('탈모', 34),
#  ('고생', 34),
#  ('밥', 34),
#  ('소화', 33),
#  ('나우', 33),
#  ('의사', 33),
#  ('관심', 33),
#  ('트리', 33),
#  ('증', 33),
#  ('제로', 33),
#  ('마늘', 33),
#  ('유씨', 33),
#  ('신경', 32),
#  ('비타', 32),
#  ('타치', 32),
#  ('보충', 32),
#  ('사서', 32),
#  ('두통', 32),
#  ('방송', 32),
#  ('한가지', 32),
#  ('블루', 32),
#  ('염', 32),
#  ('스트레스', 32),
#  ('별로', 32),
#  ('트', 32),
#  ('수술', 32),
#  ('역시', 31),
#  ('품절', 31),
#  ('판매', 31),
#  ('불면증', 31),
#  ('부담', 31),
#  ('방법', 31),
#  ('글루', 31),
#  ('고려', 31),
#  ('원래', 31),
#  ('포티', 31),
#  ('아민', 31),
#  ('듯', 31),
#  ('복', 31),
#  ('컴플렉스', 30),
#  ('센트', 30),
#  ('미국', 30),
#  ('베이직', 30),
#  ('중반', 30),
#  ('손', 30),
#  ('제일', 30),
#  ('위해', 30),
#  ('남성', 29),
#  ('주신', 29),
#  ('신제품', 29),
#  ('익스', 29),
#  ('가끔', 29),
#  ('뉴', 29),
#  ('준비', 29),
#  ('남자', 29),
#  ('가족', 29),
#  ('머리', 29),
#  ('배', 28),
#  ('술', 28),
#  ('얘기', 28),
#  ('종비', 28),
#  ('혈압', 28),
#  ('피', 28),
#  ('원료', 28),
#  ('올해', 27),
#  ('대한', 27),
#  ('두', 27),
#  ('소변', 27),
#  ('크게', 27),
#  ('속', 27),
#  ('개선', 27),
#  ('텐션', 27),
#  ('얼라이브', 27),
#  ('고혈압', 27),
#  ('포벨', 27),
#  ('임신', 27),
#  ('흡연', 27),
#  ('갑자기', 27),
#  ('양과자', 27),
#  ('파일', 27),
#  ('쪽', 26),
#  ('인', 26),
#  ('스', 26),
#  ('편', 26),
#  ('비맥', 26),
#  ('보넷', 26),
#  ('비활', 26),
#  ('허브', 26),
#  ('주문', 26),
#  ('볼', 26),
#  ('검색', 26),
#  ('이해', 26),
#  ('필요', 26),
#  ('손가락', 26),
#  ('기초', 26),
#  ('유튜버', 25),
#  ('개인', 25),
#  ('유투브', 25),
#  ('아들', 25),
#  ('여드름', 25),
#  ('시슬', 25),
#  ('보', 25),
#  ('굳이', 25),
#  ('반', 25),
#  ('멕스', 25),
#  ('유', 25),
#  ('한지', 25),
#  ('아버지', 25),
#  ('회사', 25),
#  ('구성', 25),
#  ('사실', 24),
#  ('한국', 24),
#  ('슬', 24),
#  ('근육통', 24),
#  ('기준', 24),
#  ('비멕스', 24),
#  ('가슴', 24),
#  ('적', 24),
#  ('단백질', 24),
#  ('엑셀', 24),
#  ('아주', 23),
#  ('기존', 23),
#  ('철분', 23),
#  ('권', 23),
#  ('갑상선', 23),
#  ('자꾸', 23),
#  ('액티브', 23),
#  ('킬레이트', 23),
#  ('메틸', 23),
#  ('체력', 23),
#  ('설', 23),
#  ('치료', 23),
#  ('상품', 23),
#  ('룸', 23),
#  ('간이', 23),
#  ('후반', 23),
#  ('종', 23),
#  ('손상', 23),
#  ('쌤', 23),
#  ('상태', 23),
#  ('플러스', 23),
#  ('관', 23),
#  ('메일', 23),
#  ('이건', 22),
#  ('곳', 22),
#  ('여자', 22),
#  ('저하', 22),
#  ('리틀', 22),
#  ('집', 22),
#  ('프로폴리스', 22),
#  ('의약품', 22),
#  ('가루', 22),
#  ('음식', 22),
#  ('신뢰', 22),
#  ('목적', 21),
#  ('젠', 21),
#  ('파워', 21),
#  ('영향력', 21),
#  ('일주일', 21),
#  ('아시', 21),
#  ('머', 21),
#  ('대체', 21),
#  ('복합', 21),
#  ('밴드', 21),
#  ('가든', 21),
#  ('함유', 21),
#  ('산', 20),
#  ('기분', 20),
#  ('확인', 20),
#  ('장량', 20),
#  ('장기', 20),
#  ('중이', 20),
#  ('벌써', 20),
#  ('보통', 20),
#  ('드', 20),
#  ('정상', 20),
#  ('저혈압', 20),
#  ('먹음', 20),
#  ('관절염', 20),
#  ('염증', 20),
#  ('추출', 20),
#  ('사용', 20),
#  ('진', 20),
#  ('마음', 20),
#  ('저림', 20),
#  ('의견', 19),
#  ('율', 19),
#  ('표', 19),
#  ('보기', 19),
#  ('선물', 19),
#  ('간염', 19),
#  ('거나', 19),
#  ('땐', 19),
#  ('육체', 19),
#  ('푸드', 19),
#  ('총', 19),
#  ('중복', 19),
#  ('미리', 19),
#  ('뒤', 19),
#  ('임산부', 19),
#  ('제대로', 19),
#  ('새해', 19),
#  ('별', 19),
#  ('관리', 19),
#  ('쭉', 19),
#  ('마', 19),
#  ('줄', 19),
#  ('초', 19),
#  ('상담', 19),
#  ('먼저', 19),
#  ('저리', 19),
#  ('이야기', 19),
#  ('기본', 19),
#  ('기', 18),
#  ('해주시', 18),
#  ('면역', 18),
#  ('액', 18),
#  ('습', 18),
#  ('약도', 18),
#  ('먹이', 18),
#  ('모든', 18),
#  ('어제', 18),
#  ('요새', 18),
#  ('인터넷', 18),
#  ('포', 18),
#  ('질', 18),
#  ('결과', 18),
#  ('지식', 18),
#  ('임', 18),
#  ('현상', 18),
#  ('생활', 18),
#  ('오브', 18),
#  ('식전', 17),
#  ('수고', 17),
#  ('부스터', 17),
#  ('중학생', 17),
#  ('서도', 17),
#  ('갱년기', 17),
#  ('슈퍼', 17),
#  ('함', 17),
#  ('시아노', 17),
#  ('어깨', 17),
#  ('정신', 17),
#  ('언급', 17),
#  ('티', 17),
#  ('테', 17),
#  ('영향', 17),
#  ('원인', 17),
#  ('여러', 17),
#  ('밤', 17),
#  ('무릎', 16),
#  ('이후', 16),
#  ('판토텐산', 16),
#  ('해당', 16),
#  ('며칠', 16),
#  ('작년', 16),
#  ('배출', 16),
#  ('인지', 16),
#  ('다리', 16),
#  ('면', 16),
#  ('량', 16),
#  ('거리', 16),
#  ('동영상', 16),
#  ('답', 16),
#  ('골다공증', 16),
#  ('실리', 16),
#  ('지방간', 16),
#  ('보조', 16),
#  ('장', 16),
#  ('제약', 16),
#  ('힘', 16),
#  ('대신', 16),
#  ('귀', 16),
#  ('하니', 16),
#  ('질환', 16),
#  ('초반', 16),
#  ('강의', 16),
#  ('포장', 16),
#  ('신청', 16),
#  ('공유', 16),
#  ('대부분', 16),
#  ('노', 15),
#  ('차', 15),
#  ('은단', 15),
#  ('무조건', 15),
#  ('여러가지', 15),
#  ('성인', 15),
#  ('종일', 15),
#  ('필수', 15),
#  ('효모', 15),
#  ('투퍼데', 15),
#  ('블로그', 15),
#  ('일반', 15),
#  ('주심', 15),
#  ('유한양행', 15),
#  ('해결', 15),
#  ('액티', 15),
#  ('변색', 15),
#  ('진단', 15),
#  ('큐', 15),
#  ('나이아신', 15),
#  ('브랜드', 15),
#  ('코로나', 15),
#  ('노력', 15),
#  ('식', 15),
#  ('외국', 15),
#  ('우리나라', 15),
#  ('그게', 14),
#  ('투', 14),
#  ('피크', 14),
#  ('강황', 14),
#  ('제나', 14),
#  ('는걸', 14),
#  ('목', 14),
#  ('기간', 14),
#  ('주', 14),
#  ('색', 14),
#  ('형', 14),
#  ('이면', 14),
#  ('증후군', 14),
#  ('부족', 14),
#  ('가면', 14),
#  ('맥주', 14),
#  ('임펙타민', 14),
#  ('믿음', 14),
#  ('내', 14),
#  ('편이', 14),
#  ('칼', 14),
#  ('쏙쏙', 14),
#  ('피리독신', 14),
#  ('신랑', 14),
#  ('다이어트', 14),
#  ('체', 14),
#  ('베타', 14),
#  ('간다', 14),
#  ('라면', 14),
#  ('읍', 14),
#  ('초심', 14),
#  ('경험', 14),
#  ('양', 14),
#  ('지방시', 14),
#  ('생기', 14),
#  ('혹', 14),
#  ('지인', 14),
#  ('발생', 14),
#  ('품질', 14),
#  ('이전', 13),
#  ('두드러기', 13),
#  ('번갈아', 13),
#  ('로우', 13),
#  ('놀', 13),
#  ('주의', 13),
#  ('원스', 13),
#  ('연기', 13),
#  ('타', 13),
#  ('국가', 13),
#  ('혈액', 13),
#  ('덜', 13),
#  ('이틀', 13),
#  ('식도염', 13),
#  ('상세', 13),
#  ('고등학생', 13),
#  ('거기', 13),
#  ('동시', 13),
#  ('커피', 13),
#  ('주변', 13),
#  ('변비', 13),
#  ('우루사', 13),
#  ('골', 13),
#  ('그거', 13),
#  ('끼', 13),
#  ('업그레이드', 13),
#  ('마케팅', 13),
#  ('분석', 13),
#  ('좀더', 13),
#  ('공구', 13),
#  ('여름', 13),
#  ('외', 13),
#  ('이용', 13),
#  ('쿠팡', 13),
#  ('링크', 13),
#  ('항진', 13),
#  ('씨', 13),
#  ('끝', 13),
#  ('제발', 13),
#  ('홍보', 13),
#  ('통해', 13),
#  ('와우', 13),
#  ('숙성', 13),
#  ('상황', 12),
#  ('직접', 12),
#  ('박스', 12),
#  ('점점', 12),
#  ('완전', 12),
#  ('애', 12),
#  ('겹', 12),
#  ('근육', 12),
#  ('사의', 12),
#  ('건강검진', 12),
#  ('첨가', 12),
#  ('키', 12),
#  ('비염', 12),
#  ('출시', 12),
#  ('수용성', 12),
#  ('새벽', 12),
#  ('티비', 12),
#  ('아래', 12),
#  ('자도', 12),
#  ('홍삼', 12),
#  ('발', 12),
#  ('전혀', 12),
#  ('소리', 12),
#  ('피곤', 12),
#  ('토', 12),
#  ('이나', 12),
#  ('뇌', 12),
#  ('수준', 12),
#  ('안해', 12),
#  ('코엔자임', 12),
#  ('항', 12),
#  ('위염', 12),
#  ('예정', 12),
#  ('몇개', 12),
#  ('기운', 12),
#  ('마디', 12),
#  ('기억', 12),
#  ('어지럼증', 12),
#  ('모습', 12),
#  ('목소리', 12),
#  ('값', 12),
#  ('대박', 11),
#  ('매우', 11),
#  ('코드', 11),
#  ('입술', 11),
#  ('류', 11),
#  ('활동', 11),
#  ('대웅제약', 11),
#  ('구토', 11),
#  ('션', 11),
#  ('바', 11),
#  ('진통제', 11),
#  ('나머지', 11),
#  ('괜', 11),
#  ('레시틴', 11),
#  ('효능', 11),
#  ('그동안', 11),
#  ('커큐민', 11),
#  ('종근당', 11),
#  ('마린', 11),
#  ('대가', 11),
#  ('엠', 11),
#  ('일반의약품', 11),
#  ('굿', 11),
#  ('대입', 11),
#  ('꽤', 11),
#  ('학생', 11),
#  ('살짝', 11),
#  ('확', 11),
#  ('실버', 11),
#  ('직업', 11),
#  ('젤', 11),
#  ('초기', 11),
#  ('청소년', 11),
#  ('보관', 11),
#  ('트러블', 11),
#  ('체질', 11),
#  ('마지막', 11),
#  ('치가', 11),
#  ('아예', 11),
#  ('왼쪽', 11),
#  ('일리', 11),
#  ('병', 11),
#  ('저번', 11),
#  ('유지', 11),
#  ('균', 11),
#  ('이벤트', 11),
#  ('요약', 11),
#  ('항산화제', 11),
#  ('조인트', 11),
#  ('덕', 10),
#  ('만성', 10),
#  ('재', 10),
#  ('상관', 10),
#  ('기도', 10),
#  ('나중', 10),
#  ('제의', 10),
#  ('이구', 10),
#  ('호르몬', 10),
#  ('담', 10),
#  ('콜레스테롤', 10),
#  ('시험', 10),
#  ('포진', 10),
#  ('락토', 10),
#  ('홍조', 10),
#  ('상보', 10),
#  ('컨디션', 10),
#  ('동생', 10),
#  ('사고', 10),
#  ('팩트', 10),
#  ('라이신', 10),
#  ('유투', 10),
#  ('제안', 10),
#  ('무기', 10),
#  ('프로바이오틱스', 10),
#  ('사려', 10),
#  ('절대', 10),
#  ('과잉', 10),
#  ('인상', 10),
#  ('장기간', 10),
#  ('성', 10),
#  ('직장인', 10),
#  ('유발', 10),
#  ('브로', 10),
#  ('심장', 10),
#  ('땜', 10),
#  ('스토어', 10),
#  ('용법', 10),
#  ('마카', 10),
#  ('햇', 10),
#  ('가입', 10),
#  ('에너지', 10),
#  ('초과', 10),
#  ('참조', 10),
#  ('종종', 10),
#  ('틴', 10),
#  ('막', 10),
#  ('수면', 10),
#  ('어머님', 10),
#  ('아무', 10),
#  ('뼈', 10),
#  ('도대체', 10),
#  ('누가', 10),
#  ('고요', 10),
#  ('파리', 10),
#  ('포산', 10),
#  ('쿄릭', 10),
#  ('지속', 10),
#  ('일반인', 10),
#  ('작용', 10),
#  ('전문', 10),
#  ('뿐', 10),
#  ('달성', 10),
#  ('당첨', 10),
#  ('인사', 9),
#  ('동네', 9),
#  ('나름', 9),
#  ('시중', 9),
#  ('헬스', 9),
#  ('커서', 9),
#  ('괜찬', 9),
#  ('실제', 9),
#  ('근무', 9),
#  ('입안', 9),
#  ('오줌', 9),
#  ('상이', 9),
#  ('보균자', 9),
#  ('터', 9),
#  ('포커스', 9),
#  ('제약회사', 9),
#  ('마침', 9),
#  ('심해', 9),
#  ('순환', 9),
#  ('친구', 9),
#  ('난', 9),
#  ('비프', 9),
#  ('궁금', 9),
#  ('캐나다', 9),
#  ('심', 9),
#  ('주사', 9),
#  ('답글', 9),
#  ('알러지', 9),
#  ('포스', 9),
#  ('던데', 9),
#  ('군데', 9),
#  ('근처', 9),
#  ('음', 9),
#  ('에이', 9),
#  ('컨텐츠', 9),
#  ('금', 9),
#  ('사항', 9),
#  ('제제', 9),
#  ('드릴', 9),
#  ('염산', 9),
#  ('자체', 9),
#  ('불량', 9),
#  ('그날', 9),
#  ('단일', 9),
#  ('마이', 9),
#  ('해소', 9),
#  ('맘', 9),
#  ('주행', 9),
#  ('절반', 9),
#  ('네이버', 9),
#  ('낮', 9),
#  ('수도', 9),
#  ('격일', 9),
#  ('온몸', 9),
#  ('허리', 9),
#  ('다해', 9),
#  ('된거', 9),
#  ('오일', 9),
#  ('중간', 9),
#  ('혈관', 9),
#  ('천연', 9),
#  ('인기', 9),
#  ('입문', 9),
#  ('파우더', 9),
#  ('요청', 9),
#  ('자궁', 9),
#  ('효율', 9),
#  ('비도', 9),
#  ('시대', 9),
#  ('이명', 9),
#  ('제거', 9),
#  ('더욱', 8),
#  ('입', 8),
#  ('고혈압약', 8),
#  ('글루콤', 8),
#  ('졸음', 8),
#  ('장복', 8),
#  ('잔틴', 8),
#  ('결론', 8),
#  ('비비', 8),
#  ('역류성', 8),
#  ('어르신', 8),
#  ('실수', 8),
#  ('암웨이', 8),
#  ('신분', 8),
#  ('표기', 8),
#  ('에버', 8),
#  ('방', 8),
#  ('유한', 8),
#  ('그것', 8),
#  ('어린이', 8),
#  ('체감', 8),
#  ('병행', 8),
#  ('남', 8),
#  ('헤르페스', 8),
#  ('결정', 8),
#  ('용이', 8),
#  ('서요', 8),
#  ('자고', 8),
#  ('시리즈', 8),
#  ('발전', 8),
#  ('볼때', 8),
#  ('고해', 8),
#  ('문구', 8),
#  ('조언', 8),
#  ('사랑', 8),
#  ('배송', 8),
#  ('아내', 8),
#  ('요오드', 8),
#  ('생리', 8),
#  ('캘리포니아', 8),
#  ('결석', 8),
#  ('처럼', 8),
#  ('부정맥', 8),
#  ('삐콤', 8),
#  ('제만', 8),
#  ('젤리', 8),
#  ('유통', 8),
#  ('제공', 8),
#  ('오전', 8),
#  ('이제야', 8),
#  ('수면장애', 8),
#  ('니아신', 8),
#  ('타입', 8),
#  ('보시', 8),
#  ('궁합', 8),
#  ('리보플라빈', 8),
#  ('평생', 8),
#  ('료', 8),
#  ('금방', 8),
#  ('출산', 8),
#  ('리포', 8),
#  ('칼맥디', 8),
#  ('주부', 8),
#  ('이지', 8),
#  ('박사', 8),
#  ('승인', 8),
#  ('서로', 8),
#  ('습관', 8),
#  ('대사', 8),
#  ('달라', 8),
#  ('찾기', 8),
#  ('절약', 8),
#  ('산패', 8),
#  ('쭈욱', 8),
#  ('초창', 7),
#  ('무', 7),
#  ('종로', 7),
#  ('방금', 7),
#  ('트롬', 7),
#  ('접', 7),
#  ('판토', 7),
#  ('야간', 7),
#  ('내일', 7),
#  ('위주', 7),
#  ('향', 7),
#  ('오후', 7),
#  ('의심', 7),
#  ('만하', 7),
#  ('기립', 7),
#  ('물이', 7),
#  ('륨', 7),
#  ('콤플렉스', 7),
#  ('비용', 7),
#  ('나은', 7),
#  ('이분', 7),
#  ('화학', 7),
#  ('셀', 7),
#  ('바이오', 7),
#  ('드림', 7),
#  ('선전', 7),
#  ('버', 7),
#  ('독성', 7),
#  ('초등', 7),
#  ('베리', 7),
#  ('과다복용', 7),
#  ('지도', 7),
#  ('리뉴얼', 7),
#  ('생', 7),
#  ('교대근무', 7),
#  ('재발', 7),
#  ('될런', 7),
#  ('할머니', 7),
#  ('위산', 7),
#  ('검', 7),
#  ('소화효소', 7),
#  ('디씨', 7),
#  ('반응', 7),
#  ('엑티브', 7),
#  ('사면', 7),
#  ('선', 7),
#  ('국민', 7),
#  ('개별', 7),
#  ('어지러움', 7),
#  ('순간', 7),
#  ('색소', 7),
#  ('여기저기', 7),
#  ('형광', 7),
#  ('신장결석', 7),
#  ('변질', 7),
#  ('폐암', 7),
#  ('식단', 7),
#  ('권장', 7),
#  ('손발', 7),
#  ('가용', 7),
#  ...]

# %%
key = []
value = []

for k, v in c2:
    key.append(k)
    value.append(v)

# %%
key[:30]
# Out:
# ['비타민',
#  '약사',
#  '비',
#  '제품',
#  '양제',
#  '복용',
#  '추천',
#  '영상',
#  '맥스',
#  '약',
#  '오메가',
#  '메타',
#  '정보',
#  '종합',
#  '알',
#  '축하',
#  '섭취',
#  '마그네슘',
#  '항상',
#  '도움',
#  '하루',
#  '선생님',
#  '유산균',
#  '함량',
#  '리서치',
#  '효과',
#  '구매',
#  '약국',
#  '피로',
#  '건강']

# %%
import matplotlib.pyplot as plt

# %%
key_index = list(range(1,len(key)+1))

# %%
plt.plot(key_index,value)
plt.title('Frequency')
plt.ylabel('Word Frequency')
plt.xlabel('Word Index')
plt.xticks(np.arange(0,6000,500))
plt.show()

# %%
freq_30 = value[:30]

# %%
key_30 = key[:30]

# %%
key_30
# Out:
# ['비타민',
#  '약사',
#  '비',
#  '제품',
#  '양제',
#  '복용',
#  '추천',
#  '영상',
#  '맥스',
#  '약',
#  '오메가',
#  '메타',
#  '정보',
#  '종합',
#  '알',
#  '축하',
#  '섭취',
#  '마그네슘',
#  '항상',
#  '도움',
#  '하루',
#  '선생님',
#  '유산균',
#  '함량',
#  '리서치',
#  '효과',
#  '구매',
#  '약국',
#  '피로',
#  '건강']

# %%
final_word = [fw for fw in c.most_common(30)]
final_word[:5]
# Out:
# [('비타민', 1801), ('약사', 1486), ('비', 1137), ('제품', 983), ('양제', 848)]

# %%
import networkx as nx

# %%
words = [fw[0] for fw in c.most_common(30)]

# %%
'아로나민' in words
# Out:
# False

# %%
import itertools

# %%
freq = [fw[1] for fw in c.most_common(30)]
np.mean(np.array(freq))
# Out:
# 517.6

# %%
import matplotlib.font_manager as fm

# %%
fm._rebuild()

# %%
font_fname = '/content/drive/MyDrive/Colab Notebooks/malgun.ttf'
fontprop = fm.FontProperties(fname=font_fname,size=18).get_name()

# %%
def do_sna_ko(filtered_content, selected_words):
    g = nx.Graph()
    g.add_nodes_from(selected_words)

    for pair in list(itertools.combinations(list(selected_words),2)):
        if pair[0] == pair[1]:
            continue
        for sent in filtered_content:
            if pair[0] in sent and pair[1] in sent:
                if pair in list(g.edges()) or (pair[1],pair[0]) in list(g.edges()):
                    g[pair[0]][pair[1]]['weight'] += 1
                else:
                    g.add_edge(pair[0],pair[1],weight=1)

    
    pos = nx.shell_layout(g)
    nx.draw(g,pos,font_family=fontprop)
    #nx.draw_networkx_labels(g,pos,font_family=font_fname,font_size=10)
    plt.show()
    return g

# %%
word_index = list(range(1,31))

# %%
word_index_dic = {}

for i in range(30):
    word_index_dic[words[i]] = word_index[i]

# %%
g = do_sna_ko(words_list,words[:10])

# %%
#노드 목록
print(g.nodes())
#노드들 간의 관계 정보
print(g.edges())
#전체 노드 수 확인
print(g.number_of_nodes())
#전체 tie 수
print(g.number_of_edges())
# Out:
# ['비타민', '약사', '비', '제품', '양제', '복용', '추천', '영상', '맥스', '약']
# [('비타민', '약사'), ('비타민', '비'), ('비타민', '제품'), ('비타민', '양제'), ('비타민', '복용'), ('비타민', '추천'), ('비타민', '영상'), ('비타민', '맥스'), ('비타민', '약'), ('약사', '비'), ('약사', '제품'), ('약사', '양제'), ('약사', '복용'), ('약사', '추천'), ('약사', '영상'), ('약사', '맥스'), ('약사', '약'), ('비', '제품'), ('비', '양제'), ('비', '복용'), ('비', '추천'), ('비', '영상'), ('비', '맥스'), ('비', '약'), ('제품', '양제'), ('제품', '복용'), ('제품', '추천'), ('제품', '영상'), ('제품', '맥스'), ('제품', '약'), ('양제', '복용'), ('양제', '추천'), ('양제', '영상'), ('양제', '맥스'), ('양제', '약'), ('복용', '추천'), ('복용', '영상'), ('복용', '맥스'), ('복용', '약'), ('추천', '영상'), ('추천', '맥스'), ('추천', '약'), ('영상', '맥스'), ('영상', '약'), ('맥스', '약')]
# 10
# 45

# %%
for friend in g.neighbors('비타민'):
    print(friend)
# Out:
# 약사
# 비
# 제품
# 양제
# 복용
# 추천
# 영상
# 맥스
# 약

# %%
g['비타민']
# Out:
# AtlasView({'약사': {'weight': 316}, '비': {'weight': 237}, '제품': {'weight': 250}, '양제': {'weight': 187}, '복용': {'weight': 242}, '추천': {'weight': 202}, '영상': {'weight': 165}, '맥스': {'weight': 162}, '약': {'weight': 91}})

# %%
g['복용']
# Out:
# AtlasView({'비타민': {'weight': 242}, '약사': {'weight': 175}, '비': {'weight': 164}, '제품': {'weight': 103}, '양제': {'weight': 91}, '추천': {'weight': 83}, '영상': {'weight': 85}, '맥스': {'weight': 118}, '약': {'weight': 68}})

# %%
g['맥스']
# Out:
# AtlasView({'비타민': {'weight': 162}, '약사': {'weight': 134}, '비': {'weight': 521}, '제품': {'weight': 82}, '양제': {'weight': 42}, '복용': {'weight': 118}, '추천': {'weight': 66}, '영상': {'weight': 72}, '약': {'weight': 35}})

# %%
nx.eigenvector_centrality(g)
# Out:
# {'맥스': 0.31622776601683794,
#  '복용': 0.31622776601683794,
#  '비': 0.31622776601683794,
#  '비타민': 0.31622776601683794,
#  '약': 0.31622776601683794,
#  '약사': 0.31622776601683794,
#  '양제': 0.31622776601683794,
#  '영상': 0.31622776601683794,
#  '제품': 0.31622776601683794,
#  '추천': 0.31622776601683794}
