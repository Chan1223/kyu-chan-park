# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('survey_result.csv', encoding='cp949')

# %%
df.head()
# Out:
#                          타임스탬프 1. 종합비타민 등 영양제를 섭취한 경험이 있습니까?  \
# 0  2022/06/07 2:57:19 오후 GMT+9                 예 (1-1번으로 이동)
# 1  2022/06/07 2:57:49 오후 GMT+9                 예 (1-1번으로 이동)
# 2  2022/06/07 2:59:05 오후 GMT+9                 예 (1-1번으로 이동)
# 3  2022/06/07 2:59:16 오후 GMT+9                 예 (1-1번으로 이동)
# 4  2022/06/07 3:00:13 오후 GMT+9                 예 (1-1번으로 이동)
#
#                          1-1. 섭취하신 영양제 종류를 모두 골라주세요.  \
# 0                                          비타민C;오메가3
# 1  종합비타민;비타민C;비타민B;무기질 (마그네슘, 칼슘, 철분 등);오메가3;유산균;...
# 2             종합비타민;비타민C;비타민D;유산균;루테인, 지아잔틴 등 (눈 건강)
# 3  종합비타민;비타민C;비타민D;비타민B;무기질 (마그네슘, 칼슘, 철분 등);오메가3...
# 4  종합비타민;비타민C;비타민D;비타민B;무기질 (마그네슘, 칼슘, 철분 등);오메가3...
#
#   2. 종합비타민 등 영양제를 구매한 경험이 있습니까?  \
# 0                             예
# 1                           아니오
# 2                             예
# 3                             예
# 4                             예
#
#   3. 비타민B군 영양제를 섭취한 경험이 있습니까? (아로나민골드, 비맥스메타, 엑세라민비, 임팩타민, 벤포벨 등)  \
# ...
