# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Hitters_new.csv')
data_np = data.values

# %%
data.head()
# Out:
#    Salary  Hits  Years  AtBat  HmRun  Runs  RBI  Walks  CAtBat  CHits  CHmRun  \
# 0    67.5    41      2    181      1    15   21     33     232     50       4
# 1    68.0    54      1    209      3    25   14     12     209     54       3
# 2    70.0    37      2    185      1    23    8     21     214     42       1
# 3    70.0    53      2    214      2    30   29     23     226     59       2
# 4    70.0    78      1    317      7    35   35     32     317     78       7
#
#    CRuns  CRBI  CWalks League Division  PutOuts  Assists  Errors NewLeague
# 0     20    29      45      A        E      326       29       5         A
# 1     25    14      12      A        W      102        6       3         A
# 2     30     9      24      N        E       76      127       7         A
# 3     32    32      27      N        E      109        7       3         N
# 4     35    35      32      A        E       45      122      26         A

# %%
np.random.shuffle(data_np)
X=data_np[:,1:3]

# %%
X
# Out:
# array([[77, 12],
#        [154, 6],
#        [118, 4],
#        [44, 16],
#        [136, 12],
#        [86, 4],
#        [73, 7],
#        [142, 4],
#        [110, 7],
#        [91, 13],
#        [152, 2],
#        [92, 1],
#        [71, 3],
#        [171, 6],
#        [127, 7],
#        [118, 8],
#        [46, 4],
#        [147, 6],
#        [213, 4],
#        [78, 5],
#        [69, 4],
#        [126, 11],
#        [163, 13],
#        [141, 15],
#        [169, 11],
#        [113, 1],
#        [101, 1],
#        [159, 6],
#        [101, 12],
#        [41, 2],
#        [112, 7],
#        [37, 2],
#        [86, 1],
#        [43, 13],
#        [91, 2],
#        [39, 9],
#        [110, 7],
#        [70, 15],
#        [101, 17],
#        [66, 3],
#        [144, 2],
#        [27, 4],
#        [58, 1],
#        [186, 6],
#        [139, 5],
#        [125, 13],
#        [158, 15],
#        [81, 7],
#        [127, 5],
#        [68, 18],
#        [172, 1],
#        [171, 13],
#        [52, 6],
#        [94, 9],
#        [147, 10],
#        [106, 14],
#        [112, 2],
#        [170, 6],
#        [70, 16],
#        [120, 3],
#        [140, 4],
#        [136, 10],
#        [93, 2],
#        [123, 4],
#        [103, 2],
#        [200, 4],
#        [141, 8],
#        [82, 2],
#        [113, 5],
#        [117, 1],
#        [92, 3],
#        [77, 16],
#        [102, 6],
#        [124, 7],
#        [136, 11],
#        [116, 6],
#        [135, 1],
#        [198, 5],
#        [68, 6],
#        [148, 14],
#        [82, 5],
#        [85, 7],
#        [120, 4],
#        [55, 12],
#        [95, 10],
#        [103, 8],
#        [131, 7],
#        [49, 8],
#        [85, 8],
#        [150, 14],
#        [211, 5],
#        [92, 6],
#        [65, 9],
#        [163, 4],
#        [135, 9],
#        [81, 14],
#        [52, 12],
#        [53, 2],
#        [75, 3],
#        [76, 3],
#        [81, 2],
#        [163, 3],
#        [103, 2],
#        [178, 6],
#        [168, 9],
#        [101, 3],
#        [177, 6],
#        [183, 5],
#        [39, 14],
#        [76, 8],
#        [128, 14],
#        [60, 2],
#        [148, 13],
#        [32, 8],
#        [77, 6],
#        [41, 16],
#        [139, 17],
#        [93, 5],
#        [43, 7],
#        [131, 6],
#        [149, 7],
#        [138, 3],
#        [64, 1],
#        [109, 1],
#        [123, 9],
#        [103, 6],
#        [81, 17],
#        [117, 6],
#        [73, 3],
#        [120, 8],
#        [53, 4],
#        [99, 4],
#        [137, 2],
#        [169, 8],
#        [207, 5],
#        [54, 1],
#        [58, 4],
#        [144, 9],
#        [101, 20],
#        [152, 6],
#        [163, 6],
#        [47, 6],
#        [158, 5],
#        [70, 4],
#        [53, 3],
#        [145, 11],
#        [1, 2],
#        [39, 3],
#        [56, 4],
#        [144, 8],
#        [137, 14],
#        [70, 12],
#        [122, 18],
#        [94, 13],
#        [94, 7],
#        [139, 2],
#        [70, 15],
#        [78, 12],
#        [159, 9],
#        [68, 7],
#        [157, 4],
#        [4, 1],
#        [142, 18],
#        [115, 3],
#        [152, 5],
#        [56, 12],
#        [126, 6],
#        [47, 11],
#        [43, 3],
#        [138, 3],
#        [41, 2],
#        [84, 10],
#        [72, 5],
#        [90, 10],
#        [78, 1],
#        [167, 4],
#        [42, 10],
#        [76, 5],
#        [127, 2],
#        [119, 7],
#        [168, 5],
#        [210, 6],
#        [83, 5],
#        [77, 20],
#        [96, 4],
#        [83, 9],
#        [96, 5],
#        [32, 19],
#        [96, 15],
#        [40, 3],
#        [84, 5],
#        [163, 11],
#        [110, 9],
#        [56, 2],
#        [108, 3],
#        [114, 4],
#        [60, 3],
#        [76, 4],
#        [83, 14],
#        [74, 10],
#        [73, 4],
#        [146, 6],
#        [49, 7],
#        [174, 6],
#        [157, 10],
#        [169, 7],
#        [147, 7],
#        [151, 10],
#        [174, 14],
#        [56, 5],
#        [129, 10],
#        [87, 2],
#        [223, 3],
#        [131, 14],
#        [113, 12],
#        [128, 13],
#        [179, 5],
#        [149, 1],
#        [51, 1],
#        [145, 2],
#        [141, 11],
#        [97, 4],
#        [108, 3],
#        [160, 8],
#        [80, 7],
#        [68, 1],
#        [137, 15],
#        [102, 5],
#        [159, 10],
#        [103, 15],
#        [54, 5],
#        [63, 10],
#        [92, 13],
#        [200, 13],
#        [52, 24],
#        [184, 5],
#        [70, 18],
#        [132, 3],
#        [76, 6],
#        [60, 6],
#        [130, 3],
#        [170, 11],
#        [238, 5],
#        [119, 12],
#        [57, 5],
#        [168, 18],
#        [68, 6],
#        [119, 9],
#        [104, 7],
#        [113, 4],
#        [122, 4],
#        [54, 1],
#        [132, 6],
#        [154, 14],
#        [46, 5],
#        [96, 4],
#        [66, 14],
#        [61, 17],
#        [57, 3],
#        [133, 17],
#        [161, 4],
#        [53, 9],
#        [152, 3]], dtype=object)

# %%
y = data_np[:,0]

# %%
y
# Out:
# array([450.0, 580.0, 155.0, 275.0, 875.0, 250.0, 708.333, 105.0, 490.0,
#        825.0, 200.0, 100.0, 100.0, 900.0, 1183.333, 1300.0, 180.0, 1310.0,
#        350.0, 500.0, 277.5, 737.5, 1000.0, 525.0, 750.0, 90.0, 97.5,
#        475.0, 675.0, 95.0, 750.0, 70.0, 110.0, 240.0, 125.0, 175.0, 800.0,
#        365.0, 875.0, 90.0, 165.0, 190.0, 86.5, 1300.0, 400.0, 1925.571,
#        775.0, 525.0, 700.0, 400.0, 165.0, 1800.0, 265.0, 535.0, 277.5,
#        850.0, 135.0, 1237.5, 1050.0, 175.0, 200.0, 725.0, 150.0, 1220.0,
#        100.0, 250.0, 925.0, 110.0, 425.0, 120.0, 145.0, 700.0, 415.0,
#        550.0, 850.0, 600.0, 172.0, 1175.0, 305.0, 1861.46, 425.0, 300.0,
#        185.0, 1300.0, 100.0, 326.667, 780.0, 375.0, 362.5, 1000.0, 740.0,
#        300.0, 650.0, 750.0, 750.0, 475.0, 400.0, 70.0, 140.0, 155.0, 75.0,
#        200.0, 105.0, 740.0, 1200.0, 195.0, 1350.0, 775.0, 275.0, 341.667,
#        1500.0, 90.0, 700.0, 135.0, 670.0, 260.0, 950.0, 350.0, 286.667,
#        550.0, 787.5, 160.0, 75.0, 115.0, 1260.0, 325.0, 320.0, 100.0,
#        100.0, 600.0, 225.0, 87.5, 175.0, 530.0, 1600.0, 75.0, 340.0,
#        1940.0, 487.5, 940.0, 765.0, 245.0, 662.5, 250.0, 75.0, 500.0,
#        2127.333, 75.0, 230.0, 960.0, 900.0, 225.0, 535.0, 600.0, 875.0,
#        160.0, 450.0, 416.667, 1043.333, 425.0, 640.0, 920.0, 1450.0,
#        300.0, 625.0, 250.0, 385.0, 450.0, 120.0, 145.0, 67.5, 800.0,
#        130.0, 450.0, 70.0, 210.0, 900.0, 385.0, 202.5, 875.0, 612.5, 90.0,
#        431.5, 200.0, 150.0, 600.0, 300.0, 500.0, 733.333, 90.0, 400.0,
#        1900.0, 560.0, 90.0, 110.0, 475.0, 137.0, 240.0, 450.0, 737.5,
#        110.0, 815.0, 300.0, 657.0, 420.0, 950.0, 1150.0, 2460.0, 1041.667,
#        190.0, 750.0, 91.5, 365.0, 850.0, 740.0, 587.5, 575.0, 140.0, 70.0,
#        155.0, 500.0, 210.0, 215.0, 1670.0, 700.0, 70.0, 933.333, 80.0,
#        517.143, 430.0, 297.5, 341.667, 1100.0, 2412.5, 750.0, 630.0,
#        325.0, 215.0, 250.0, 700.0, 480.0, 1000.0, 1975.0, 595.0, 247.5,
#        776.667, 191.0, 850.0, 750.0, 550.0, 350.0, 68.0, 1008.333, 750.0,
#        175.0, 275.0, 250.0, 235.0, 140.0, 773.333, 625.0, 512.5, 215.0],
#       dtype=object)

# %%
from sklearn.tree import DecisionTreeRegressor
tree_reg = DecisionTreeRegressor(max_depth=2)
tree_reg.fit(X, y)
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
tree_reg.score(X, y)
# Out:
# 0.5052302826383642

# %% [markdown]
# ## 시각화

# %%
from sklearn import tree
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (3,3), dpi=300)
tree.plot_tree(tree_reg)
plt.show()
fig.savefig('tree_reg.png')

# squared_error = RSS
# RSS 를 관측치의 수로 나누어주면 MSE
# Value = 해당 그룹 관측치의 평균값
